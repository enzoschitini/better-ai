# %% [markdown]
# # 🎨 Acquarello
#
# **Transforme ideias em imagens.**
# Da palavra à imagem, ou de uma imagem a outra — sempre no seu estilo.
#
# ![Streamlit](https://img.shields.io/badge/Streamlit-app-FF4B4B?logo=streamlit&logoColor=white)
# ![Python](https://img.shields.io/badge/Python-3.10+-3776AB?logo=python&logoColor=white)
# ![IA](https://img.shields.io/badge/IA-Geração%20de%20Imagem-6E56CF)
#
# ---

# %% [markdown]
# O **Acquarello** é uma aplicação de geração de imagem por IA, construída em **Streamlit**, que coloca o poder dos modelos generativos na mão de qualquer pessoa — sem código, sem complicação. Descreva o que imagina e receba uma imagem; ou envie uma imagem existente e reinvente-a. Em ambos os casos, você define o **estilo visual** direto na barra lateral e vê o resultado ganhar a sua cara.

# %% [markdown]
# ### ✨ Destaques
#
# - 🖋️ **Texto → Imagem** — descreva uma cena e deixe a IA criá-la.
# - 🖼️ **Imagem → Imagem** — parta de uma imagem e transforme-a em algo novo.
# - 🎚️ **Estilo sob controle** — escolha e ajuste o estilo pela barra lateral.
# - ⚡ **Simples de usar** — interface intuitiva, pensada para qualquer usuário.

# %% [markdown]
# ### Links úteis
#
# | Título | Link |
# | --- | --- |
# | 💻 **Código-fonte (GitHub)** | [Ir para o repositório](https://github.com/enzoschitini/better-ai/blob/production/src/web_applications/applications/acquarello.py) |
# | ▶️ **Como executar o projeto** | [Guia de instalação](<Streamlit Applications/Content Generator.ipynb>) |
# | ⌨️ **Comando do terminal** | `streamlit run web_app.py` |
# | 🌐 **Testar agora (Streamlit)** | http://localhost:8501/acquarello |

# %% [markdown]
# ## Contexto
#
# Modelos generativos de imagem estão entre os avanços mais impressionantes da IA recente — mas, na prática, ainda intimidam quem não é técnico: exigem configuração, prompts complexos e ferramentas dispersas. O **Acquarello** nasce para resolver isso, reunindo geração por texto, geração por imagem e controle de estilo em **uma única interface acessível**. A proposta é aproximar qualquer pessoa da criação visual com IA — do curioso ao criativo — mostrando que essa tecnologia pode ser poderosa *e* simples ao mesmo tempo.

# %% [markdown]
# ## Casos de uso

# %% [markdown]
# ## 1. Geração a partir de texto (*text-to-image*)

# %% [markdown]
# #### *Uma frase vira uma imagem.* Ideal para criar conceitos, ilustrações e cenas do zero

# %% [markdown]
# #### *"Gere uma imagem aquarela com cores bem vibrantes e coloridas de duas crianças brincando com uma pipa na calçada"*
#
# ![](https://lh3.googleusercontent.com/rd-d/ALs6j_Gg-HQMU3MV4K8Mfpqp1sWHmC06pJ34AxUUVMsXwpfBI_q0sG4xHa-os7richuyWeJhA0IJJKmTlOgGchbglVU9eLJgHr5h85gtr8F4AuaKvBff7AR0wu5igTJ3HgTxaqq7z8m6CROlQrRuPYKkg66VVqAAWrgBdbaU3amT3HGWnfkRvAw3mcGu23F2QSsTRB48mX4kNkn5kcjWnTixqAr4F81SgyLvRKG69-VnodeHugUvtFTXKyelK51-ZzTpSFN1TBN6G0LRyjd0HD-8e5lBd0gNSDK4vTdLqt5P1Widn7CTn_ql8WdlObmHgMKV8KL9jrZP_AlQzFfS3Tny2VzA-srTgACJqtJtCxcXRl1xWX63OzI_0VypM5RQkkA_YfNaJ1Xx00hBWcMcP5YUrB84VzaNb9
# ![](https://lh3.googleusercontent.com/rd-d/ALs6j_FnFuMOK86uLGMwWwNky4sLWpSAV3tBCm3OXg-sx4zjgroZl8o_HjwevrmAk50lOsLDs1a7K854kwWi8IURFbpldscJYjdY8H0zc4uW647Texy5YgrrK0luGF9zfAwy0Gi_RXrkdFVgQ6ypz2fRMA6xUSrj_GzhIcSWPbBBntIO5kBm6b14xcaSYOVcBHha0YkxPT9SA6goUTvkyvI3LM9Dao5vLr6u_0UaLGgPS9ELI4_no0tbDrhZm3PSJ_fYvF06-enbQ3DEfaF7iJfOcUksiyT6-H14VqwD_sqEbcJNbDMGBggtitgqcYnHgWN5laUTkxxS1tFcWpNN56wcPxLuzRT5YGYaOqMkd4LGS0QBWSZaBhPJlyjYA8McVAAyOiBq6U0avbbW1YFJZIy_WT9eoj5JbbXI253Bi7KUTUdEXSL6SlutLfar9l03Xmcy0PHPizj7TecTAFEO6lPK7NNR9ZE6alDJOzupfdRUZ3NjlahX3g9xdnafljrDVxfJop6sh_UKNWWoYCi063xCNuctwlVOAYGg85g_H9eFb6Zocc3HM7lBkMMnAHxjG7edT49mPF0gFJFGqwmUx5IftZKBRjpvGf3OKqLINhpq99jwFJTDaUvGbAg-qrUsJxZNoe-Juwj-92E2gsICjeQozjL-B_DNjNdeLJQtBruZWd8GE21HRBLVAyg9AO1a_Z20dkoOjZieXL3fOMZaAsLg1CO2sI5muM6yrAQBvL1h2Sj5XMed0S6heJxUhU7bQ2nIQSk0I4IhFvcofVfbQvDAoxdKV0SQlwxvLBtdVhJwu65maZcZZ35YyrXH_vBDkWVxJZvr11mMSnTwRu6yNRS2KBsVJ1KZ9lm9wlrUwdm22DqEzqunykGlsQBTky8qAk99XdDS5dE9ca77iylKb_iO3DiQByZrgjh7lGsRse0jp22_J2KNv3Uz1uH80R5oehg-WiOrHYRbXbMihY_noblLXXP9LfW7QwDOuOFObkvnY99DpkotOigcnctGlNg1fqPF2mMsXp2372Ot21tW4D-Zj23cb4httz0PmSOifWLC7V-h_gH_2yKUmjNpNQjwsPcekRamHZehbKNd4K3KKZC-jvc75UfRI8URQg=w1608-h914?auditContext=prefetch)
#
# ---

# %% [markdown]
# ### 2. Geração a partir de imagem (*image-to-image*)
#
# #### *Uma imagem se transforma em outra.* Perfeito para reinterpretar, remixar ou refinar visuais existentes.

# %% [markdown]
# #### Imagem original
#
# ![](https://lh3.googleusercontent.com/u/0/d/1zYTyDmSnQce43TSEkHscS-1IFfUCYZaR=w1608-h914-iv1?auditContext=prefetch)
#
# #### Imagem com estilo Anime aplicado
#
# ![](https://lh3.googleusercontent.com/u/0/d/1K4NHmrJfAzpvzwCQ42Wo3uOkyTobW0nJ=w1608-h914-iv1?auditContext=prefetch)

# %% [markdown]
# #### Imagem original
#
# ![](https://lh3.googleusercontent.com/u/0/d/1G6seyaT6QZmIl6Sh0RSCjcWi-7jFmPH_=w2552-h914-iv1?auditContext=prefetch)
#
# #### Imagem com estilo Cartoon aplicado
#
# ![](https://lh3.googleusercontent.com/u/0/d/18W7e2uSVoxHB_sxP6KNzifGp_CbZK1lp=w2552-h914-iv1?auditContext=prefetch)

# %% [markdown]
# #### Imagem original
#
# ![](https://lh3.googleusercontent.com/u/0/d/1Hi8tlEsSW47EhX1JeCvN4WzxKJSOplq2=w1608-h914-iv1?auditContext=prefetch)
#
# #### Imagem com estilo Rabisco aplicado
#
# ![](https://lh3.googleusercontent.com/u/0/d/1MtD9E80jHkiiMjksmZvizCObql2qbtIb=w1608-h914-iv1?auditContext=prefetch)
