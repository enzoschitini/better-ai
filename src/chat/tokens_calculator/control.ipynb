# %%
import sys
import json
from bson import ObjectId

sys.path.append("..")

from utils.mongo_manage import MongoDBManager

mongo = MongoDBManager()

# %%
dic2 = {"business_id": "0010",
       "plan": {"name": "Pro", "status": "activated", 
                "resorce": {"tokens":{"monthly_budget_input_tokens": 1000, "monthly_budget_output_tokens": 1000, 
                                      "monthly_budget_total_tokens": 1000},
                                      
                             "cost":{"monthly_budget_input_cost_usd": "10", "monthly_budget_output_cost_usd": "10", 
                                     "monthly_budget_total_cost_usd": "10"}},

                "tokens":{"input_tokens": 0, "output_tokens": 0, "total_tokens": 0},
                "cost":{"input_cost_usd": "0.0", "output_cost_usd": "0.0", "total_cost_usd": "0.0"}}}

mongo.salvar_payload(
    database_name="TokensUsage",
    collection_name="BusinessAccountManage",
    payload=dic2
)
# Out:
# {'status': 'success', 'inserted_id': '690761c750f9ef2142de9946'}

# %%
def listar():
    documentos = mongo.buscar_documentos(
        database_name="TokensUsage",
        collection_name="ProcessTokensUsage",
        filtro={}
    )
    for doc in documentos:
        print(json.dumps(doc, indent=4, default=str))

# %%
mongo.buscar_documentos(
    database_name="TokensUsage",
    collection_name="BusinessAccountManage",
    filtro={"business_id": "0010"}
)[0]
# Out:
# {'_id': '690761c750f9ef2142de9946',
#  'business_id': '0010',
#  'plan': {'name': 'Pro',
#   'status': 'activated',
#   'resorce': {'tokens': {'monthly_budget_input_tokens': 1000,
#     'monthly_budget_output_tokens': 1000,
#     'monthly_budget_total_tokens': 1000},
#    'cost': {'monthly_budget_input_cost_usd': '10',
#     'monthly_budget_output_cost_usd': '10',
#     'monthly_budget_total_cost_usd': '10'}},
#   'tokens': {'input_tokens': 0, 'output_tokens': 0, 'total_tokens': 0},
#   'cost': {'input_cost_usd': '0.0',
#    'output_cost_usd': '0.0',
#    'total_cost_usd': '0.0'}},
#  '_created_at': datetime.datetime(2025, 11, 2, 13, 51, 3, 279000)}

# %%
listar()
# Out:
# {
#     "_id": "690760beca7224abef183bab",
#     "session_id": "16bb7fd5-c225-4e24-9d43-805aacd43f3d",
#     "business_id": "0010",
#     "input": "Oi",
#     "response": "Oi! Como posso ajud\u00e1-lo hoje?",
#     "tempo_execucao_s": 3.93,
#     "status": "success",
#     "tokens_estimados": {
#         "input": {
#             "parts": {
#                 "system": {
#                     "caracters": 803,
#                     "tokens_estimated": 173
#                 },
#                 "chat_history": {
#                     "caracters": 32,
#                     "tokens_estimated": 10
#                 },
#                 "tools": {
#                     "caracters": 2677,
#                     "tokens_estimated": 659
#                 },
#                 "tool_response": {
#                     "caracters": 0,
#                     "tokens_estimated": 0
#                 }
#             },
#             "combined": {
#                 "caracters": 3514,
#                 "tokens_estimated": 842
#             }
#         },
#         "output": {
#             "caracters": 29,
#             "tokens_estimated": 8
#         },
#         "total": {
#             "caracters": 3543,
#             "tokens_estimated": 842
#         }
#     },
#     "cost": {
#         "modelo": "gpt-4o-mini",
#         "input_tokens": 842,
#         "output_tokens": 8,
#         "total_tokens": 850,
#         "input_cost_usd": "0.000126",
#         "output_cost_usd": "0.000005",
#         "total_cost_usd": "0.000131"
#     },
#     "_created_at": "2025-11-02 13:46:38.417000"
# }

# %%
mongo.listar_databases_e_colecoes()

# %%
def delete():
    mongo.deletar_colecao_ou_database(
        database_name="TokensUsage",
        collection_name="BusinessAccountManage"
    )
    mongo.deletar_colecao_ou_database(
        database_name="TokensUsage",
        collection_name="ProcessTokensUsage"
    )

delete()
# Out:
# 🧹 Coleção 'BusinessAccountManage' deletada de 'TokensUsage'
# 🧹 Coleção 'ProcessTokensUsage' deletada de 'TokensUsage'
