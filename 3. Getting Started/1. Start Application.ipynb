# %%
print("OK")
# Out:
# L'esecuzione di celle con 'better-ai (Python 3.12.12)' richiede il pacchetto ipykernel.
#
# Installa 'ipykernel' nell'ambiente Python.
#
# Comando: 'c:/Users/enzo_silva/better-ai/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# ```bash
# git checkout production
# git pull
# ```

# %% [markdown]
# ```bash
#
# ```

# %% [markdown]
# Create Virtual Environment
#
# ```bash
# python -m venv .venv
# ```

# %% [markdown]
# Activate Virtual Environment
#
# ```bash
# .\.venv\Scripts\Activate.ps1 or .venv\Scripts\activate.bat
# ```
#
# ```bash
# (.venv) PS C:\Users\user_name\better-ai>
# ```

# %% [markdown]
# Install Libraries
#
# ```bash
# uv sync
# ```
#
# ```bash
# pip install requeriments.txt
# ```

# %% [markdown]
# Run API
#
# ```bash
# uvicorn app:app --reload
# ```

# %% [markdown]
# ```python
# INFO:     Will watch for changes in these directories: ['C:\\Users\\user_name\\better-ai']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [2200] using StatReload
# 2026-04-09 12:57:07,683 - app.py - line: 64 - INFO -
#
# ╔═════════════════════════════════════════════════════════════════════════╗
#
#     ██████╗ ███████╗████████╗████████╗███████╗██████╗      █████╗ ██╗ ✦
#     ██╔══██╗██╔════╝╚══██╔══╝╚══██╔══╝██╔════╝██╔══██╗    ██╔══██╗██║
#     ██████╔╝█████╗     ██║      ██║   █████╗  ██████╔╝    ███████║██║
#     ██╔══██╗██╔══╝     ██║      ██║   ██╔══╝  ██╔══██╗    ██╔══██║██║
#     ██████╔╝███████╗   ██║      ██║   ███████╗██║  ██║    ██║  ██║██║
#     ╚═════╝ ╚══════╝   ╚═╝      ╚═╝   ╚══════╝╚═╝  ╚═╝    ╚═╝  ╚═╝╚═╝
#
# ╚═════════════════════════════════════════════════════════════════════════╝
#
#                     ✦  Where intelligence finds purpose. ✦
#
#
# INFO:     Started server process [12468]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ```
