# %% [markdown]
# # A beautiful UI for your Agents
# A beautiful, open-source interface for interacting with AI agents
#
# ![alt text](image.png)
#
# ## Install Node.JS
# [Node.JS](https://nodejs.org/pt-br)
#
# [Download](https://nodejs.org/pt-br/download)
#
# > node --version
#
# > local: "C:\Program Files\nodejs"
#
# ## Get Started with Agent UI
# To clone the Agent UI, run the following command in your terminal:
#
# ```bash
# npx create-agent-ui@latest
# ```
#
# Enter y to create a new project, install dependencies, then run the agent-ui using:
#
# ```bash
# C:\Users\schit>cd agent-ui
# ```
#
# ```bash
# C:\Users\schit\agent-ui>npm run dev
# ```
#
# Open http://localhost:3000 to view the Agent UI, but remember to connect to your local agents.
#
#
# > Local:        http://localhost:3000
# > Network:      http://10.5.0.2:3000
#
# ## Minimal setup
#
# ```bash
# import os
# from dotenv import load_dotenv
#
# #os.environ["AGNO_TELEMETRY"] = "false"
# #AGNO_TELEMETRY = os.getenv("AGNO_TELEMETRY")
#
# from agno.agent import Agent
# from agno.models.openai import OpenAIChat
# from agno.os import AgentOS
#
# load_dotenv()
#
# assistant = Agent(
#     name="Assistant",
#     model=OpenAIChat(id="gpt-4.1-mini"),
#     instructions=["You are a helpful AI assistant."],
#     markdown=True,
# )
#
# agent_os = AgentOS(
#     id="my-first-os",
#     description="My first AgentOS",
#     agents=[assistant],
# )
#
# app = agent_os.get_app()
#
# if __name__ == "__main__":
#     # Default port is 7777, change with port=...
#     agent_os.serve(app="minimal_setup:app", reload=True)
#
# ```
#
# ## AgnoUI.bat
#
# ```bash
# @echo off
# cd C:\Users\schit\agent-ui
# npm run dev
# pause
# ```
#
#
# ### Others links:
#
# [Agent UI](https://docs-v1.agno.com/agent-ui/introduction#get-started-with-agent-ui)
#
# [Agent OS](https://docs.agno.com/examples/agent-os/overview)
#
# [AG-UI](https://docs.agno.com/agent-os/interfaces/ag-ui/introduction)
#
# [GitHub](https://github.com/agno-agi/agno)
#
# ---
#
# Author: Enzo Schitini
